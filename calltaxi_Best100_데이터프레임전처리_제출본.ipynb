# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager  # 크롬드라이버 자동업데이트

# %%
service = Service(executable_path=ChromeDriverManager().install())
wd = webdriver.Chrome(service=service)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# There is no [win32] chromedriver for browser 101.0.4951 in cache
# Trying to download new driver from https://chromedriver.storage.googleapis.com/101.0.4951.41/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\shong\.wdm\drivers\chromedriver\win32\101.0.4951.41]

# %%
from datetime import datetime, timedelta # 20180501 부터 10일간 데이터 반환 
base = datetime.strptime('20190101', '%Y%m%d') 
numdays = 1216
date_list = [(base + timedelta(days=x)).strftime('%Y%m%d') for x in range(0, numdays)] 
print(date_list)
# Out:
# ['20190101', '20190102', '20190103', '20190104', '20190105', '20190106', '20190107', '20190108', '20190109', '20190110', '20190111', '20190112', '20190113', '20190114', '20190115', '20190116', '20190117', '20190118', '20190119', '20190120', '20190121', '20190122', '20190123', '20190124', '20190125', '20190126', '20190127', '20190128', '20190129', '20190130', '20190131', '20190201', '20190202', '20190203', '20190204', '20190205', '20190206', '20190207', '20190208', '20190209', '20190210', '20190211', '20190212', '20190213', '20190214', '20190215', '20190216', '20190217', '20190218', '20190219', '20190220', '20190221', '20190222', '20190223', '20190224', '20190225', '20190226', '20190227', '20190228', '20190301', '20190302', '20190303', '20190304', '20190305', '20190306', '20190307', '20190308', '20190309', '20190310', '20190311', '20190312', '20190313', '20190314', '20190315', '20190316', '20190317', '20190318', '20190319', '20190320', '20190321', '20190322', '20190323', '20190324', '
# ...

# %%
type(date_list[0])
# Out:
# str

# %%
for i in date_list:
    wd.get('http://m.calltaxi.sisul.or.kr/api/open/newEXCEL0002.asp?key=95b2363ff7d0b895e5d28f8598c08ec2&sDate=' + i)

# %%
import os
list_df = os.listdir('C://Users//shong//Downloads')

# %%
list_df = list_df[1:]

# %%
len(list_df)
# Out:
# 1217

# %%
import os
list_df = os.listdir('C://Users//shong//Downloads')

# %%
list_df
# Out:
# ['desktop.ini',
#  'open_data_02_2022-05-12 (1).xls',
#  'open_data_02_2022-05-12 (10).xls',
#  'open_data_02_2022-05-12 (100).xls',
#  'open_data_02_2022-05-12 (11).xls',
#  'open_data_02_2022-05-12 (12).xls',
#  'open_data_02_2022-05-12 (13).xls',
#  'open_data_02_2022-05-12 (14).xls',
#  'open_data_02_2022-05-12 (15).xls',
#  'open_data_02_2022-05-12 (16).xls',
#  'open_data_02_2022-05-12 (17).xls',
#  'open_data_02_2022-05-12 (18).xls',
#  'open_data_02_2022-05-12 (19).xls',
#  'open_data_02_2022-05-12 (2).xls',
#  'open_data_02_2022-05-12 (20).xls',
#  'open_data_02_2022-05-12 (21).xls',
#  'open_data_02_2022-05-12 (22).xls',
#  'open_data_02_2022-05-12 (23).xls',
#  'open_data_02_2022-05-12 (24).xls',
#  'open_data_02_2022-05-12 (25).xls',
#  'open_data_02_2022-05-12 (26).xls',
#  'open_data_02_2022-05-12 (27).xls',
#  'open_data_02_2022-05-12 (28).xls',
#  'open_data_02_2022-05-12 (29).xls',
#  'open_data_02_2022-05-12 (3).xls',
#  'open_data_02_2022-05-12 (30).xls',
# ...

# %%
list_df = list_df[1:]

# %%
list_df
# Out:
# ['open_data_02_2022-05-12 (1).xls',
#  'open_data_02_2022-05-12 (10).xls',
#  'open_data_02_2022-05-12 (100).xls',
#  'open_data_02_2022-05-12 (11).xls',
#  'open_data_02_2022-05-12 (12).xls',
#  'open_data_02_2022-05-12 (13).xls',
#  'open_data_02_2022-05-12 (14).xls',
#  'open_data_02_2022-05-12 (15).xls',
#  'open_data_02_2022-05-12 (16).xls',
#  'open_data_02_2022-05-12 (17).xls',
#  'open_data_02_2022-05-12 (18).xls',
#  'open_data_02_2022-05-12 (19).xls',
#  'open_data_02_2022-05-12 (2).xls',
#  'open_data_02_2022-05-12 (20).xls',
#  'open_data_02_2022-05-12 (21).xls',
#  'open_data_02_2022-05-12 (22).xls',
#  'open_data_02_2022-05-12 (23).xls',
#  'open_data_02_2022-05-12 (24).xls',
#  'open_data_02_2022-05-12 (25).xls',
#  'open_data_02_2022-05-12 (26).xls',
#  'open_data_02_2022-05-12 (27).xls',
#  'open_data_02_2022-05-12 (28).xls',
#  'open_data_02_2022-05-12 (29).xls',
#  'open_data_02_2022-05-12 (3).xls',
#  'open_data_02_2022-05-12 (30).xls',
# ...

# %%
len(list_df)
# Out:
# 1216

# %%
book = xw.Book('C://Users//shong//Downloads//open_data_02_2022-05-12 (90).xls')
df = book.sheets(1).used_range.options(pd.DataFrame).value  
df
# Out:
#               시/도 시/군/구   동/읍/면   승차건수
# 승차일자
# 2019-04-01  서울특별시   노원구  상계6.7동  101.0
# 2019-04-01  서울특별시  서대문구     신촌동   92.0
# 2019-04-01  서울특별시   노원구    하계1동   88.0
# 2019-04-01  서울특별시   은평구     역촌동   70.0
# 2019-04-01  서울특별시   마포구   성산제2동   59.0
# ...           ...   ...     ...    ...
# 2019-04-01  서울특별시   도봉구   방학제1동   11.0
# 2019-04-01  서울특별시  동대문구  답십리제3동   11.0
# 2019-04-01  서울특별시  동대문구     용두동   11.0
# 2019-04-01  서울특별시   마포구   망원제2동   11.0
# 2019-04-01  서울특별시   서초구    방배4동   11.0
#
# [100 rows x 4 columns]

# %%
list_df_1 = list_df[:100]
# Out:
# ['open_data_02_2022-05-12 (1).xls',
#  'open_data_02_2022-05-12 (10).xls',
#  'open_data_02_2022-05-12 (100).xls',
#  'open_data_02_2022-05-12 (11).xls',
#  'open_data_02_2022-05-12 (12).xls',
#  'open_data_02_2022-05-12 (13).xls',
#  'open_data_02_2022-05-12 (14).xls',
#  'open_data_02_2022-05-12 (15).xls',
#  'open_data_02_2022-05-12 (16).xls',
#  'open_data_02_2022-05-12 (17).xls',
#  'open_data_02_2022-05-12 (18).xls',
#  'open_data_02_2022-05-12 (19).xls',
#  'open_data_02_2022-05-12 (2).xls',
#  'open_data_02_2022-05-12 (20).xls',
#  'open_data_02_2022-05-12 (21).xls',
#  'open_data_02_2022-05-12 (22).xls',
#  'open_data_02_2022-05-12 (23).xls',
#  'open_data_02_2022-05-12 (24).xls',
#  'open_data_02_2022-05-12 (25).xls',
#  'open_data_02_2022-05-12 (26).xls',
#  'open_data_02_2022-05-12 (27).xls',
#  'open_data_02_2022-05-12 (28).xls',
#  'open_data_02_2022-05-12 (29).xls',
#  'open_data_02_2022-05-12 (3).xls',
#  'open_data_02_2022-05-12 (30).xls',
# ...

# %%
list_df_1 = list_df[:100]
list_df_2 = list_df[100:200]
list_df_3 = list_df[200:300]
list_df_4 = list_df[300:400]
list_df_5 = list_df[400:500]
list_df_6 = list_df[500:600]
list_df_7 = list_df[600:700]
list_df_8 = list_df[700:800]
list_df_9 = list_df[800:900]
list_df_10 = list_df[900:1000]
list_df_11= list_df[1000:1100]
list_df_12 = list_df[1100:1200]

# %%
final_df = pd.DataFrame()

for i in list_df_1 :
    book = xw.Book('C://Users//shong//Downloads//' + i)
    df = book.sheets(1).used_range.options(pd.DataFrame).value  
    final_df = final_df.append(df)

# %%
for i in list_df_2 :
    book = xw.Book('C://Users//shong//Downloads//' + i)
    df = book.sheets(1).used_range.options(pd.DataFrame).value  
    final_df = final_df.append(df)

# %%
final_df
# Out:
#               시/도 시/군/구   동/읍/면  승차건수
# 승차일자
# 2019-01-02  서울특별시   노원구    하계1동  80.0
# 2019-01-02  서울특별시  서대문구     신촌동  75.0
# 2019-01-02  서울특별시   노원구  상계6.7동  72.0
# 2019-01-02  서울특별시   은평구     역촌동  59.0
# 2019-01-02  서울특별시   마포구   성산제2동  57.0
# ...           ...   ...     ...   ...
# 2019-07-20  서울특별시   양천구     목5동   6.0
# 2019-07-20  서울특별시   은평구   응암제1동   6.0
# 2019-07-20  서울특별시   종로구     평창동   6.0
# 2019-07-20  서울특별시    중구     황학동   6.0
# 2019-07-20  서울특별시   중랑구    망우본동   6.0
#
# [20000 rows x 4 columns]

# %%
for i in list_df_3 :
    book = xw.Book('C://Users//shong//Downloads//' + i)
    df = book.sheets(1).used_range.options(pd.DataFrame).value  
    final_df = final_df.append(df)

# %%
for i in list_df_4 :
    book = xw.Book('C://Users//shong//Downloads//' + i)
    df = book.sheets(1).used_range.options(pd.DataFrame).value  
    final_df = final_df.append(df)

# %%
for i in list_df_5 :
    book = xw.Book('C://Users//shong//Downloads//' + i)
    df = book.sheets(1).used_range.options(pd.DataFrame).value  
    final_df = final_df.append(df)

# %%
final_df
# Out:
#               시/도 시/군/구   동/읍/면  승차건수
# 승차일자
# 2019-01-02  서울특별시   노원구    하계1동  80.0
# 2019-01-02  서울특별시  서대문구     신촌동  75.0
# 2019-01-02  서울특별시   노원구  상계6.7동  72.0
# 2019-01-02  서울특별시   은평구     역촌동  59.0
# 2019-01-02  서울특별시   마포구   성산제2동  57.0
# ...           ...   ...     ...   ...
# 2020-05-15  서울특별시   동작구     흑석동   9.0
# 2020-05-15  서울특별시   서초구    방배2동   9.0
# 2020-05-15  서울특별시   성동구     마장동   9.0
# 2020-05-15  서울특별시   성북구     안암동   9.0
# 2020-05-15  서울특별시   양천구     목1동   9.0
#
# [50000 rows x 4 columns]

# %%
for i in list_df_6 :
    book = xw.Book('C://Users//shong//Downloads//' + i)
    df = book.sheets(1).used_range.options(pd.DataFrame).value  
    final_df = final_df.append(df)

# %%
for i in list_df_7 :
    book = xw.Book('C://Users//shong//Downloads//' + i)
    df = book.sheets(1).used_range.options(pd.DataFrame).value  
    final_df = final_df.append(df)

# %%
for i in list_df_8 :
    book = xw.Book('C://Users//shong//Downloads//' + i)
    df = book.sheets(1).used_range.options(pd.DataFrame).value  
    final_df = final_df.append(df)

# %%
for i in list_df_9 :
    book = xw.Book('C://Users//shong//Downloads//' + i)
    df = book.sheets(1).used_range.options(pd.DataFrame).value  
    final_df = final_df.append(df)

# %%
for i in list_df_10 :
    book = xw.Book('C://Users//shong//Downloads//' + i)
    df = book.sheets(1).used_range.options(pd.DataFrame).value  
    final_df = final_df.append(df)

# %%
for i in list_df_11 :
    book = xw.Book('C://Users//shong//Downloads//' + i)
    df = book.sheets(1).used_range.options(pd.DataFrame).value  
    final_df = final_df.append(df)

# %%
final_df
# Out:
#               시/도 시/군/구   동/읍/면  승차건수
# 승차일자
# 2019-01-02  서울특별시   노원구    하계1동  80.0
# 2019-01-02  서울특별시  서대문구     신촌동  75.0
# 2019-01-02  서울특별시   노원구  상계6.7동  72.0
# 2019-01-02  서울특별시   은평구     역촌동  59.0
# 2019-01-02  서울특별시   마포구   성산제2동  57.0
# ...           ...   ...     ...   ...
# 2022-01-05  서울특별시   구로구     수궁동  12.0
# 2022-01-05  서울특별시   금천구   시흥제1동  12.0
# 2022-01-05  서울특별시   노원구  상계3.4동  12.0
# 2022-01-05  서울특별시  동대문구    청량리동  12.0
# 2022-01-05  서울특별시   동작구     대방동  12.0
#
# [110000 rows x 4 columns]

# %%
for i in list_df_12 :
    book = xw.Book('C://Users//shong//Downloads//' + i)
    df = book.sheets(1).used_range.options(pd.DataFrame).value  
    final_df = final_df.append(df)

# %%
book = xw.Book('C://Users//shong//Downloads//open_data_02_2022-05-12.xls')
df_0101 = book.sheets(1).used_range.options(pd.DataFrame).value  
final_df = final_df.append(df_0101)

# %%
df = final_df.copy()

# %%
df
# Out:
#               시/도 시/군/구   동/읍/면  승차건수
# 승차일자
# 2019-01-02  서울특별시   노원구    하계1동  80.0
# 2019-01-02  서울특별시  서대문구     신촌동  75.0
# 2019-01-02  서울특별시   노원구  상계6.7동  72.0
# 2019-01-02  서울특별시   은평구     역촌동  59.0
# 2019-01-02  서울특별시   마포구   성산제2동  57.0
# ...           ...   ...     ...   ...
# 2019-01-01    경기도   광명시    소하1동   3.0
# 2019-01-01    경기도  남양주시     별내면   3.0
# 2019-01-01  서울특별시   강북구    삼각산동   3.0
# 2019-01-01  서울특별시   강북구   수유제3동   3.0
# 2019-01-01  서울특별시   강서구   등촌제1동   3.0
#
# [120100 rows x 4 columns]

# %%
df['승차일자'] = df.index

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#           시/도 시/군/구   동/읍/면  승차건수       승차일자
# 0       서울특별시   노원구    하계1동  80.0 2019-01-02
# 1       서울특별시  서대문구     신촌동  75.0 2019-01-02
# 2       서울특별시   노원구  상계6.7동  72.0 2019-01-02
# 3       서울특별시   은평구     역촌동  59.0 2019-01-02
# 4       서울특별시   마포구   성산제2동  57.0 2019-01-02
# ...       ...   ...     ...   ...        ...
# 120095    경기도   광명시    소하1동   3.0 2019-01-01
# 120096    경기도  남양주시     별내면   3.0 2019-01-01
# 120097  서울특별시   강북구    삼각산동   3.0 2019-01-01
# 120098  서울특별시   강북구   수유제3동   3.0 2019-01-01
# 120099  서울특별시   강서구   등촌제1동   3.0 2019-01-01
#
# [120100 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['시/도', '시/군/구', '동/읍/면', '승차건수', '승차일자'], dtype='object')

# %%
df = df[['승차일자','시/도', '시/군/구', '동/읍/면', '승차건수']]

# %%
df
# Out:
#              승차일자    시/도 시/군/구   동/읍/면  승차건수
# 0      2019-01-02  서울특별시   노원구    하계1동  80.0
# 1      2019-01-02  서울특별시  서대문구     신촌동  75.0
# 2      2019-01-02  서울특별시   노원구  상계6.7동  72.0
# 3      2019-01-02  서울특별시   은평구     역촌동  59.0
# 4      2019-01-02  서울특별시   마포구   성산제2동  57.0
# ...           ...    ...   ...     ...   ...
# 120095 2019-01-01    경기도   광명시    소하1동   3.0
# 120096 2019-01-01    경기도  남양주시     별내면   3.0
# 120097 2019-01-01  서울특별시   강북구    삼각산동   3.0
# 120098 2019-01-01  서울특별시   강북구   수유제3동   3.0
# 120099 2019-01-01  서울특별시   강서구   등촌제1동   3.0
#
# [120100 rows x 5 columns]

# %%
df_sort_value = df.sort_values(by=df.columns[0],ascending=True)
df_sort_value
# Out:
#              승차일자    시/도 시/군/구        동/읍/면  승차건수
# 120099 2019-01-01  서울특별시   강서구        등촌제1동   3.0
# 120026 2019-01-01  서울특별시   마포구          상암동   7.0
# 120027 2019-01-01  서울특별시   성북구          종암동   7.0
# 120028 2019-01-01  서울특별시   송파구         문정2동   7.0
# 120029 2019-01-01  서울특별시   은평구          구산동   7.0
# ...           ...    ...   ...          ...   ...
# 119971 2022-04-15  서울특별시   마포구        망원제1동  16.0
# 119972 2022-04-15  서울특별시   마포구        성산제1동  16.0
# 119973 2022-04-15  서울특별시   서초구         반포4동  16.0
# 119975 2022-04-15  서울특별시   성북구          안암동  16.0
# 119950 2022-04-15  서울특별시   종로구  종로1.2.3.4가동  19.0
#
# [120100 rows x 5 columns]

# %%
df_sort_value = df_sort_value.reset_index(drop=True)

# %%
df_sort_value
# Out:
#              승차일자    시/도 시/군/구        동/읍/면  승차건수
# 0      2019-01-01  서울특별시   강서구        등촌제1동   3.0
# 1      2019-01-01  서울특별시   마포구          상암동   7.0
# 2      2019-01-01  서울특별시   성북구          종암동   7.0
# 3      2019-01-01  서울특별시   송파구         문정2동   7.0
# 4      2019-01-01  서울특별시   은평구          구산동   7.0
# ...           ...    ...   ...          ...   ...
# 120095 2022-04-15  서울특별시   마포구        망원제1동  16.0
# 120096 2022-04-15  서울특별시   마포구        성산제1동  16.0
# 120097 2022-04-15  서울특별시   서초구         반포4동  16.0
# 120098 2022-04-15  서울특별시   성북구          안암동  16.0
# 120099 2022-04-15  서울특별시   종로구  종로1.2.3.4가동  19.0
#
# [120100 rows x 5 columns]

# %%
df_sort_value.to_csv('C://Users//shong//Downloads//calltaxi_Best100.csv', encoding='utf-8-sig', index=False)
